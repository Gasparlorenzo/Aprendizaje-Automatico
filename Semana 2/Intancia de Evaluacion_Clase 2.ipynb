# %%
import pandas as pd
# Carga del archivo ventas.csv
ventas = pd.read_csv(
    r'C:\Users\usuario\OneDrive\Desktop\3! Cuatrimestre\03 - Aprendizaje Automático\01 - Ejercicios Entrega\Semana 2\ventas.csv',
    encoding="ISO-8859-1", index_col= 'id_venta')
# Mostramos las primeras filas del dataset
print(ventas.head())
# Out:
#                fecha  producto  cantidad  precio_unitario
# id_venta
# 1         2026-01-10  Notebook         2             1200
# 2         2026-01-12     Mouse         5               25
# 3         2026-01-15   Teclado         3               45
# 4         2026-01-18   Monitor         1              300

# %%
import pandas as pd
# Cargamos el archivo clientes.json
clientes = pd.read_json(
    r'C:\Users\usuario\OneDrive\Desktop\3! Cuatrimestre\03 - Aprendizaje Automático\01 - Ejercicios Entrega\Semana 2\clientes.json')
# Mostramos la cantidad total de clientes
print("Cantidad total de clientes:", clientes.shape[0])
# Out:
# Cantidad total de clientes: 3

# %%
import pandas as pd
# Cargamos el archivo inventario.xlsx
inventario = pd.read_excel(
    r'C:\Users\usuario\OneDrive\Desktop\3! Cuatrimestre\03 - Aprendizaje Automático\01 - Ejercicios Entrega\Semana 2\inventario.xlsx')
# Calculamos el promedio de stock
promedio_stock = inventario['stock'].mean()

# Mostramos el resultado
print("Promedio de stock:", promedio_stock)
# Out:
# Promedio de stock: 26.25
