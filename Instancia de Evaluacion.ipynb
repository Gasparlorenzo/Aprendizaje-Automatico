# %%
import pandas as pd

# Cargamos el archivo ventas.csv desde la ruta que venimos usando
ventas = pd.read_csv(
    r'C:\Users\usuario\OneDrive\Desktop\3! Cuatrimestre\03 - Aprendizaje Automático\01 - Ejercicios\ventas.csv',
    encoding="ISO-8859-1"
)

# Mostramos las primeras filas del dataset
ventas.head()
# Out:
#    id_venta     producto    categoria  cantidad  precio_unitario       fecha  \
# 0         1      Teclado  PerifÃ©rico         2            15000  2026-04-01
# 1         2        Mouse  PerifÃ©rico         1             8000  2026-04-02
# 2         3      Monitor     Pantalla         1           120000  2026-04-03
# 3         4     Notebook  Computadora         1           450000  2026-04-04
# 4         5  Auriculares        Audio         3             7000  2026-04-05
#
#    id_cliente
# 0           1
# 1           2
# 2           3
# 3           1
# 4           4

# %%
# Cargamos el archivo clientes.json
clientes = pd.read_json(
    r'C:\Users\usuario\OneDrive\Desktop\3! Cuatrimestre\03 - Aprendizaje Automático\01 - Ejercicios\clientes.json'
)

# Mostramos la cantidad total de clientes
print("Cantidad total de clientes:", clientes.shape[0])
# Out:
# Cantidad total de clientes: 5

# %%
# Cargamos el archivo inventario.xlsx
inventario = pd.read_excel(
    r'C:\Users\usuario\OneDrive\Desktop\3! Cuatrimestre\03 - Aprendizaje Automático\01 - Ejercicios\inventario.xlsx'
)

# Calculamos el promedio de stock
promedio_stock = inventario['stock'].mean()

# Mostramos el resultado
print("Promedio de stock:", promedio_stock)
# Out:
# Promedio de stock: 36.8

# %%
# Cargamos el archivo inventario.xlsx
inventario = pd.read_excel(
    r'C:\Users\usuario\OneDrive\Desktop\3! Cuatrimestre\03 - Aprendizaje Automático\01 - Ejercicios\inventario.xlsx'
)

# Calculamos el promedio de stock por producto
promedio_por_producto = inventario.groupby('producto')['stock'].mean()

# Mostramos el resultado
print(promedio_por_producto)
# Out:
# producto
# Auriculares     60.0
# Disco SSD       40.0
# Impresora       15.0
# Monitor         20.0
# Mouse          100.0
# Notebook        10.0
# Parlantes       25.0
# Tablet          18.0
# Teclado         50.0
# Webcam          30.0
# Name: stock, dtype: float64
